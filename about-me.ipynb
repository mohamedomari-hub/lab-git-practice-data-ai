# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Mohamed Omari"
topic = "AI Engineering"
reason = "I want to complement my data analysis and math modelling (systems biology) skills with AI and machine learning knowledge to be able to apply it in my research and future career"
fun_fact = "Curious to learn new things and challenge myself"

print(f"Hi! My name is {name}. I’m excited to learn {topic} because {reason}. A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Mohamed Omari. I’m excited to learn AI Engineering because I want to complement my data analysis and math modelling (systems biology) skills with AI and machine learning knowledge to be able to apply it in my research and future career.. A fun fact about me is: Curious to learn new things and challenge myself.
